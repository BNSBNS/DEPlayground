# %% [markdown]
# # Foundation Notebook Index
#
# This notebook maps the implementation assets to `design3.md`.
#
# Use the notebooks by topic, not by week alone. `design3.md` is phase-based for planning; this notebook set is domain-based for practice.

# %% [markdown]
# ## Notebook Map
#
# | Notebook | Focus | Maps to Design 3 | Primary Output |
# | --- | --- | --- | --- |
# | `01_python_foundations.ipynb` | Python language fluency, stdlib, modules, typing, packaging | Phase 1 | `stdlib-first` data toolkit |
# | `02_python_internals_and_performance.ipynb` | Python object model, internals, memory, runtime, profiling, GIL | Phase 1 | benchmark and internals notes |
# | `03_software_engineering_foundations.ipynb` | testing, linting, type checks, refactoring, packaging | Phase 1 | tested and maintainable toolkit |
# | `04_dsa_problem_solving_foundations.ipynb` | core data structures and problem-solving patterns | Phase 2 | data-structure lab |
# | `05_sql_database_foundations.ipynb` | SQL, query plans, indexes, MVCC, time-series schemas | Phase 2 | query-performance lab |
# | `06_systems_linux_networking_foundations.ipynb` | processes, memory, file descriptors, shell/Linux tooling, DNS/TCP/HTTP | Phase 3 | debugging workbook |
# | `07_data_platform_foundations.ipynb` | idempotency, retries, data contracts, schema evolution, observability | Phase 3 | reliable ingestion prototype |
# | `08_systems_design_foundations.ipynb` | requirements, estimation, interfaces, failure modes, tradeoffs | Phase 3 | small design notes |
# | `09_trading_data_ml_foundations.ipynb` | market data correctness, point-in-time features, reproducibility | Phase 4 | canonical model + feature spec |

# %% [markdown]
# ## Recommended Sequence
#
# Follow the notebooks in numeric order.
#
# 1. `01` builds Python language fluency.
# 2. `02` deepens Python internals and performance reasoning.
# 3. `03` turns that into engineering discipline.
# 4. `04-05` build structural reasoning in DSA and databases.
# 5. `06-08` build systems, platform reliability, and design reasoning.
# 6. `09` bridges into the trading AI/ML vertical.
#
# Only start `09` after the foundation quality gate in `design3.md` is met.

# %% [markdown]
# ## Working Rhythm
#
# For each study session:
#
# 1. Review one concept from the current notebook.
# 2. Complete one drill or one small code experiment.
# 3. Write one short explanation note in your own words.
# 4. Update progress at the end of the session.
#
# Progress levels:
#
# - `Understand`
# - `Can implement`
# - `Can explain under pressure`

# %%
progress = {
    "01_python_foundations": {"understand": [], "implement": [], "explain": []},
    "02_python_internals_and_performance": {"understand": [], "implement": [], "explain": []},
    "03_software_engineering_foundations": {"understand": [], "implement": [], "explain": []},
    "04_dsa_problem_solving_foundations": {"understand": [], "implement": [], "explain": []},
    "05_sql_database_foundations": {"understand": [], "implement": [], "explain": []},
    "06_systems_linux_networking_foundations": {"understand": [], "implement": [], "explain": []},
    "07_data_platform_foundations": {"understand": [], "implement": [], "explain": []},
    "08_systems_design_foundations": {"understand": [], "implement": [], "explain": []},
    "09_trading_data_ml_foundations": {"understand": [], "implement": [], "explain": []},
}

progress
